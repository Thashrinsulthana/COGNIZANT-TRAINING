# %%
class Car:
    colour="red"
    brand="BMW"
    SPEED=120
car1=Car
 
print(car1.colour)
print(car1.brand)
# Out:
# red
# BMW

# %%
class MyCar:
    colour="red"
    brand="BMW"
    SPEED=120
print(MyCar.colour)
print(MyCar.brand)
# Out:
# red
# BMW

# %%
class Student:
     def __init__(self,name,age):
         self.name = name
         self.age = age
s1=Student("Kavita",32)
print(s1.name)
print(s1.age)
# Out:
# Kavita
# 32
