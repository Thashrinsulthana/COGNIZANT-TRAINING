# %%
name=("kavita")
print(name)
# Out:
# kavita

# %%
name=("kavita")
emailid=("abc@gmail.com")
print(name)
print(emailid)
# Out:
# kavita
# abc@gmail.com

# %%
city="Pune"
print(city[3])
# Out:
# e

# %%
city="Pune"
print(city[-2])
# Out:
# n

# %%
name="kavita"
print(name[1:5])
# Out:
# avit

# %%
name="kavita"
print(len(name))
# Out:
# 6

# %%
first="kavita"
second="yadav"
print(first+" "+second)
# Out:
# kavita yadav

# %%
print("Hello\n "*3)
# Out:
# Hello
#  Hello
#  Hello

# %%
name="kavita"
print(name.upper())
# Out:
# KAVITA

# %%
name="KAVITA"
print(name.lower())
# Out:
# kavita

# %%
s="I like Java"
print(s.replace("Java","Python"))
# Out:
# I like Python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name:")
print("welcome",name)
# Out:
# Enter the name: Thashrin
# welcome Thashrin

# %%
p="Python"
print(p[::-1])
# Out:
# nohtyP

# %%
def add(a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def multiply(a,b):
    return a*b
print(multiply(10,20))
# Out:
# 200

# %%
def multiply(a,b,c=0):
    return a*b*c
print(multiply(10,20))
print(multiply(10,20,30))
# Out:
# 0
# 6000

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def student(*marks):
    print(sum(marks))
student(32,45,78)
student(52,96,45,75,45,69,45)
# Out:
# 155
# 427
