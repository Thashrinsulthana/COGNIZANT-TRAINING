# %%
print("hello")
# Out:
# hello

# %%
a=14
b=45
c=a+b
print(c)
# Out:
# 59

# %%
marks=[80,75,56,67]
print(marks[1])
# Out:
# 75

# %%
marks=[80,75,56,67]
print(marks[1])
# Out:
# 75

# %%
print(marks[0])
# Out:
# 80

# %%
marks=[23,45,67,89,89]
print(marks[4])
# Out:
# 89

# %%
i=1
for i in range(1,10):
    print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
marks=75
if marks>=35:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
s="python"
s[-len(s)]
# Out:
# 'p'
