# %%
name=["abc","def","ghi","jkl","mno"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# abc
# def
# ghi
# jkl
# mno

# %%
marks=[41,82,39,74,65]
it=iter(marks)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 41
# 82
# 39
# 74
# 65

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen=numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3

# %%
file =open("demo.txt","w")
file.write("hello student")
file.close()

# %%
file =open("demo.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# hello student
