# %%
list=[1,2,3,4]
print(list[3])
# Out:
# 4

# %%
num=10
print(num/0)
print("last line of the program")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 num=10
# ----> 2 print(num/0)
#       3 print("last line of the program")
#
# ZeroDivisionError: division by zero

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# cannot divide by zero

# %%
try:
    file=open("abc.txt","r")
except FileNotFoundError:
    print("file doesn't exist")
# Out:
# file doesn't exist

# %%
try:
   age=int(input("Enter the age:"))
except ValueError:
    print("Enter valid age or around age")
# Out:
# Enter the age: 56.5
# Enter valid age or around age

# %%
try:
    name=input("Enter your name:")
except NameError:
    print("write characters only")
# Out:
# Enter your name: 76
